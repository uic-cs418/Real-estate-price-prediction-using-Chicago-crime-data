# %%
import pandas as pd
import numpy as np

house_df = pd.read_excel('real_eastate_data_1.xlsx', index_col=0)

# %%
house_df.head()
# Out:
#             Month of Period End Median Sale Price  Median Sale Price MoM   \
# Region
# Chicago, IL          2012-02-01             $130K                  -0.071
# Chicago, IL          2012-03-01             $148K                   0.135
# Chicago, IL          2012-04-01             $170K                   0.151
# Chicago, IL          2012-05-01             $178K                   0.047
# Chicago, IL          2012-06-01             $200K                   0.127
#
#              Median Sale Price YoY   Homes Sold  Homes Sold MoM   \
# Region
# Chicago, IL                  -0.037        1499           -0.193
# Chicago, IL                   0.054        1975            0.318
# Chicago, IL                   0.095        1960           -0.008
# Chicago, IL                   0.139        2392            0.220
# Chicago, IL                   0.069        2696            0.127
#
#              Homes Sold YoY   New Listings  New Listings MoM   \
# Region
# ...

# %%
house_df.groupby('Median Sale Price').size().sort_values(ascending=False).reset_index().head()
# Out:
#   Median Sale Price    0
# 0              $45K  108
# 1              $50K  101
# 2             $125K   97
# 3             $400K   95
# 4             $260K   93

# %%
## simple visualization
